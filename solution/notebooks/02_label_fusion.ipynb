# %% [markdown]
# # 02 — Label Fusion
#
# Decode RADD, GLAD-L, GLAD-S2. Compare sources. Build fused pseudo ground truth.

# %%
import sys
sys.path.insert(0, "..")
sys.path.insert(0, "../..")

import numpy as np
import matplotlib.pyplot as plt
import rasterio

from solution.config import *
from solution.src.data.inventory import *
from solution.src.data.loader import *

# %%
# Start working here...
