# %% [markdown]
# # 01 — Exploratory Data Analysis
#
# Inventory tiles, visualize modalities, check label agreement, understand data quality.

# %%
import sys
sys.path.insert(0, "..")
sys.path.insert(0, "../..")

import numpy as np
import matplotlib.pyplot as plt
import rasterio

from solution.config import *
from solution.src.data.inventory import *
from solution.src.data.loader import *

# %%
# Start working here...
